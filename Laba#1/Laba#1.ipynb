# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# ### Импорт библиотек

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')
sns.set(style="ticks")
# %matplotlib inline

# %% [markdown]
# ### Загрузка данных

# %%
happy_data = pd.read_csv('data.csv', sep = ',' )

# %% [markdown]
# ## 2)Основные характеристики датасета

# %%
# Первые пять строк датасета
happy_data.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# 1             4.0    0.588       1         Redbone  Childish Gambino
# 2             4.0    0.173       1    Xanny Family            Future
# 3             4.0    0.230       1  Master Of None       Beach House
# 4             4.0    0.904       1  Parallel Lines       Junior Boys

# %%
# Размер датасета
happy_data.shape
# Out:
# (2017, 17)

# %%
# Количество нулевых элементов
happy_data.isnull().sum()
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
 # Колонки и их типы данных
happy_data.dtypes
# Out:
# Unnamed: 0            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# speechiness         float64
# tempo               float64
# time_signature      float64
# valence             float64
# target                int64
# song_title           object
# artist               object
# dtype: object

# %%
# Описание датасета
happy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
#  16  artist            2017 non-null   object
# dtypes: float64(10), int64(5), object(2)
# memory usage: 268.0+ KB

# %%
# Статистические данные
happy_data.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %%
# Удаляем столбец iso_code
happy_data = happy_data.drop('key', axis = 1)

# %%
# Первые пять строк датасета
happy_data.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# 1             4.0    0.588       1         Redbone  Childish Gambino
# 2             4.0    0.173       1    Xanny Family            Future
# 3             4.0    0.230       1  Master Of None       Beach House
# 4             4.0    0.904       1  Parallel Lines       Junior Boys

# %%
# Определим уникальные значения для целевого признака
happy_data['acousticness'].unique()
# Out:
# array([0.0102  , 0.199   , 0.0344  , ..., 0.000586, 0.00106 , 0.00857 ])

# %% [markdown]
# ## 3) Визуальное исследование датасета

# %%
# Гистограммы для всех признаков
happy_data.hist(bins=30, figsize = (15,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd111ed6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108fa0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108f5dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108f13910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd108ed0c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108e89910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108e46d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108dfd950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd108e064d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108dbce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108db1d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108d699d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd108d26d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108cdca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108c9ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd108c52a50>]],
#       dtype=object)

# %%
# Диаграммы рассеяние для всех признаков
plt.figure(figsize=(12,6))
sns.pairplot(happy_data)

# %%
# Одномерное распределение вероятности
sns.boxplot(x=happy_data['tempo'])

# %%
sns.violinplot(x=happy_data['duration_ms'])

# %% [markdown]
# ## 4) Корреляции признаков

# %%
corr_matrix = happy_data.corr()

# %%
corr_matrix['acousticness']
# Out:
# Unnamed: 0          0.133055
# acousticness        1.000000
# danceability       -0.179894
# duration_ms         0.071536
# energy             -0.646319
# instrumentalness    0.144397
# liveness           -0.117126
# loudness           -0.562021
# mode                0.068028
# speechiness        -0.099893
# tempo              -0.127596
# time_signature     -0.190353
# valence            -0.152227
# target             -0.129627
# Name: acousticness, dtype: float64

# %%
sns.heatmap(happy_data.corr(), annot=True, fmt='.3f')
